# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/20200701.export.CSV', sep = '\t')
# Out:
# /opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#    932509376  20190702  201907  2019  2019.4986 Unnamed: 5  Unnamed: 6  \
# 0  932509377  20190702  201907  2019  2019.4986        AUS  AUSTRALIAN
# 1  932509378  20190702  201907  2019  2019.4986        AUS  AUSTRALIAN
# 2  932509379  20190702  201907  2019  2019.4986        AUS  AUSTRALIAN
# 3  932509380  20190702  201907  2019  2019.4986        BRA      BRAZIL
# 4  932509381  20190702  201907  2019  2019.4986        BUS     AIRLINE
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9  ...  -1521348 4.3  \
# 0        AUS        NaN        NaN  ...       NaN   1
# 1        AUS        NaN        NaN  ...       NaN   1
# 2        AUS        NaN        NaN  ...       NaN   1
# 3        BRA        NaN        NaN  ...   -631243   4
# 4        NaN        NaN        NaN  ...  -1502554   4
#
#   Wellington, New Zealand (general), New Zealand.1 NZ.1 NZ00.1  -41.3.1  \
# 0                                            China   CH     CH  35.0000
# ...

# %%
df['Unnamed: 8'].unique()
# Out:
# array([nan, 'TAL', 'OPC', 'EEC', 'UNO', 'NAT', 'AMN', 'IRC', 'IMF', 'SCE',
#        'ASN', 'WTO', 'XFM', 'ITP', 'HRW', 'ALQ', 'WAS', 'CEM', 'IAD',
#        'ICC', 'GOE', 'ADB', 'MSF', 'ARL', 'PLO', 'COE', 'WEF', 'ICG',
#        'SAD', 'GCC', 'AFB', 'BCA', 'GOS', 'EBR', 'FID', 'SAA'],
#       dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156133 entries, 0 to 156132
# Data columns (total 58 columns):
# 932509376                                                                  156133 non-null int64
# 20190702                                                                   156133 non-null int64
# 201907                                                                     156133 non-null int64
# 2019                                                                       156133 non-null int64
# 2019.4986                                                                  156133 non-null float64
# Unnamed: 5                                                                 141450 non-null object
# Unnamed: 6                                                                 141450 non-null object
# Unnamed: 7                                                                 84793 non-null object
# ...

# %%
df[df['Wellington, New Zealand (general), New Zealand.1'] == 'Australia']
# Out:
#         932509376  20190702  201907  2019  2019.4986 Unnamed: 5   Unnamed: 6  \
# 1       932509378  20190702  201907  2019  2019.4986        AUS   AUSTRALIAN
# 85      932509462  20200701  202007  2020  2020.4959        NaN          NaN
# 86      932509463  20200701  202007  2020  2020.4959        NaN          NaN
# 537     932509914  20200701  202007  2020  2020.4959        AUS    AUSTRALIA
# 539     932509916  20200701  202007  2020  2020.4959        AUS    AUSTRALIA
# ...           ...       ...     ...   ...        ...        ...          ...
# 155496  932733476  20200701  202007  2020  2020.4959        LEG      SENATOR
# 155614  932733594  20200701  202007  2020  2020.4959        NZL  NEW ZEALAND
# 155615  932733595  20200701  202007  2020  2020.4959        NZL  NEW ZEALAND
# 155616  932733596  20200701  202007  2020  2020.4959        NZL         KIWI
# 155617  932733597  20200701  202007  2020  2020.4959        NZL  NEW ZEALAND
#
# ...

# %%
df.loc[0, 'https://www.nzherald.co.nz/nz/news/article.cfm?c_id=1&objectid=12344522']
# Out:
# 'https://www.abc.net.au/news/2020-06-30/australia-unveils-10-year-defence-strategy/12408232'

# %%
df2 = pd.read_csv('../../data/20200717.gkg.csv', sep = '\t')
df2.head()
# Out:
#        DATE  NUMARTS COUNTS  \
# 0  20200717        1    NaN
# 1  20200717        1    NaN
# 2  20200717        1    NaN
# 3  20200717        1    NaN
# 4  20200717        1    NaN
#
#                                               THEMES  \
# 0  TAX_FNCACT;TAX_FNCACT_ACTRESS;SOC_QUARANTINE;C...
# 1  TAX_FNCACT;TAX_FNCACT_INSIDER;WB_698_TRADE;COR...
# 2  CRISISLEX_T11_UPDATESSYMPATHY;CRISISLEX_C07_SA...
# 3  TAX_FNCACT;TAX_FNCACT_AGENT;ENV_GREEN;WB_507_E...
# 4  TAX_DISEASE;TAX_DISEASE_CORONAVIRUS;GENERAL_HE...
#
#                                            LOCATIONS  \
# 0  4#Mumbai, Maharashtra, India#IN#IN16#18.975#72...
# 1  3#San Diego, California, United States#US#USCA...
# 2  4#Kirkcaldy, Fife, United Kingdom#UK#UKV1#56.1...
# 3                    1#United Kingdom#UK#UK#54#-4#UK
# 4  1#China#CH#CH#35#105#CH;2#Florida, United Stat...
#
#                                              PERSONS  \
# 0  tiger zinda hai;kareena kapoor khan;vicky kaus...
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88205 entries, 0 to 88204
# Data columns (total 11 columns):
# DATE             88205 non-null int64
# NUMARTS          88205 non-null int64
# COUNTS           15169 non-null object
# THEMES           81298 non-null object
# LOCATIONS        88205 non-null object
# PERSONS          72508 non-null object
# ORGANIZATIONS    72632 non-null object
# TONE             88205 non-null object
# CAMEOEVENTIDS    44742 non-null object
# SOURCES          88205 non-null object
# SOURCEURLS       88205 non-null object
# dtypes: int64(2), object(9)
# memory usage: 7.4+ MB

# %%
df2['LOCATIONS'].unique()
# Out:
# array(['4#Mumbai, Maharashtra, India#IN#IN16#18.975#72.8258#-2092174',
#        '3#San Diego, California, United States#US#USCA#32.7153#-117.157#1661377;1#United States#US#US#39.828175#-98.5795#US;3#Washington, Washington, United States#US#USDC#38.8951#-77.0364#531871;3#San Francisco, California, United States#US#USCA#37.7749#-122.419#277593',
#        '4#Kirkcaldy, Fife, United Kingdom#UK#UKV1#56.1167#-3.16667#-2600330;1#United Kingdom#UK#UK#54#-4#UK;4#Rosyth, Fife, United Kingdom#UK#UKV1#56.0333#-3.43333#-2606540',
#        ..., '1#China#CH#CH#35#105#CH;1#Sri Lanka#CE#CE#7#81#CE',
#        '1#Kenya#KE#KE#1#38#KE;1#Nigeria#NI#NI#10#8#NI;1#New Zealand#NZ#NZ#-42#174#NZ;1#Thailand#TH#TH#15#100#TH;1#Netherlands#NL#NL#52.5#5.75#NL;1#Egypt#EG#EG#27#30#EG;1#Brazil#BR#BR#-10#-55#BR;1#Moldova#MD#MD#47#29#MD;4#Geneva, Genè, Switzerland#SZ#SZ07#46.1956#6.14811#-2552151;1#Saudi Arabia#SA#SA#25#45#SA;1#Switzerland#SZ#SZ#47#8#SZ',
# ...
